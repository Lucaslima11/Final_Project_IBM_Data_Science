# %% [markdown]
# ## Final Project - The Battle of Neighborhoods

# %% [markdown]
# <h3>1. Introduction </h3>

# %% [markdown]
# Rio de Janeiro is well-known as place with multiple beaches, sun most part of the year, happiness, and carnival. As place that mix both nature and buildings, it attracts lots of turists regularly throughout a normal year. So normally, before move on a travel to Brazil is interesting to find useful information about trustful places to visit.

# %% [markdown]
# <h3> 2. Describing the situation</h3>

# %% [markdown]
# Imagine a situation where a tourist wants to visit places beyond famous beaches or any other touristic places, moreover, as a nature explorer, he wants to know some waterfalls, because he read it in a forum on internet. In order to achieve this goal, and considering his hotel is near Copacabana beach, he needs to capture different locations and analyze ratings as a touchstone to feel safe.

# %% [markdown]
# <h3> 3. Gathering the data from Foursquare </h3>

# %% [markdown]
# First of all, all libraries required to make all the analysis are detailed below.

# %%
import pandas as pd
import numpy as np
import folium
import requests
import matplotlib.pyplot as plt

from geopy.geocoders import Nominatim

from IPython.display import Image 
from IPython.core.display import HTML

# %% [markdown]
# Credentials, version and limit must be provided, in order to use the Foursquare API.

# %%
CLIENT_ID = 'WVW0HSJAVFJYY1EOL2EAVB30SLXIGM5LNIFEZX3QF5NAMMKB' # your Foursquare ID
CLIENT_SECRET = 'FMBXRFDAWCPH14NJCAUZEU2GXRWVBYN0XECPUM5NIELTKZMI' # your Foursquare Secret
ACCESS_TOKEN = '5O34IB2J505FIA3Y2YMRH33U03RXAXDAWLDXUEYX4XKKP3P4' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100

# %% [markdown]
# After that, we need to find the first reference, which is Copacabana, the place that the tourist has been hosted. To do that, the address is expressed in a generic way just to ensure the reference is appropriated to compare with the final results.

# %%
address = 'Copacabana, Rio de Janeiro, Brazil'

#Defining latitude and longitude for Copacabana
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -22.9719642 -43.1843432

# %% [markdown]
# The place was setted, so it is time to write a query with a portuguese word for waterfall (cachoeira). This choice was made, because using the english word gave poor results.

# %%
#defining the desired query
search_query = 'cachoeira'
radius = 20000

# %% [markdown]
# Now it is time to run the Foursquare API. This request is joining multiple variables as 'search_query' and all credentials.

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

# %%
#show json results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60bd5a1f87a1184dc79e533f'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4bc1cda674a9a5938e3ed2f6',
#     'name': 'Cachoeira do Chuveiro',
#     'location': {'address': 'Estrada Dona Castorina',
#      'crossStreet': 'Parque Nacional da Tijuca',
#      'lat': -22.96632435745544,
#      'lng': -43.24286763469779,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.96632435745544,
#        'lng': -43.24286763469779}],
#      'distance': 6031,
#      'postalCode': '22460-320',
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Estrada Dona Castorina (Parque Nacional da Tijuca)',
#       'Rio de Janeiro, RJ',
#       '22460-320']},
#     'categories': [{'id': '4eb1d4dd4b900d56c88a45fd',
#       'name': 'River',
#       'pluralName': 'Rivers',
#       'shortName': 'River',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '501a7ff8e4b04620d5ff1ceb',
#     'name': 'Cachoeira do Jardim Botânico',
#     'location': {'address': 'Jardim Botânico do Rio de Janeiro',
#      'lat': -22.969507564955872,
#      'lng': -43.224679009779194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.969507564955872,
#        'lng': -43.224679009779194}],
#      'distance': 4143,
#      'postalCode': '22470-180',
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Jardim Botânico do Rio de Janeiro',
#       'Rio de Janeiro, RJ',
#       '22470-180']},
#     'categories': [{'id': '56aa371be4b08b9a8d573560',
#       'name': 'Waterfall',
#       'pluralName': 'Waterfalls',
#       'shortName': 'Waterfall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5416fc37498ec124d60fac7c',
#     'name': 'Cachoeira do Horto',
#     'location': {'lat': -22.965870160643846,
#      'lng': -43.23518197261494,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.965870160643846,
#        'lng': -43.23518197261494}],
#      'distance': 5254,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '56aa371be4b08b9a8d573560',
#       'name': 'Waterfall',
#       'pluralName': 'Waterfalls',
#       'shortName': 'Waterfall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '53556b5b498ed5c9b3a22f54',
#     'name': 'Cachoeira dos Primatas',
#     'location': {'lat': -22.981304168701172,
#      'lng': -43.22185516357422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.981304168701172,
#        'lng': -43.22185516357422}],
#      'distance': 3982,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4bf58dd8d48988d159941735',
#       'name': 'Trail',
#       'pluralName': 'Trails',
#       'shortName': 'Trail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '4c8d062555fba093eb8b64ab',
#     'name': 'Cachoeira dos Primatas',
#     'location': {'address': 'Parque Nacional da Tijuca',
#      'lat': -22.95841227320093,
#      'lng': -43.228017936258745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.95841227320093,
#        'lng': -43.228017936258745}],
#      'distance': 4723,
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Parque Nacional da Tijuca', 'Rio de Janeiro, RJ']},
#     'categories': [{'id': '4eb1d4dd4b900d56c88a45fd',
#       'name': 'River',
#       'pluralName': 'Rivers',
#       'shortName': 'River',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '587e4862102f470580acfb47',
#     'name': 'Cachoeira das Paineiras',
#     'location': {'address': 'Paineiras',
#      'lat': -22.954767,
#      'lng': -43.230966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.954767,
#        'lng': -43.230966}],
#      'distance': 5147,
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Paineiras', 'Rio de Janeiro, RJ']},
#     'categories': [{'id': '56aa371be4b08b9a8d573560',
#       'name': 'Waterfall',
#       'pluralName': 'Waterfalls',
#       'shortName': 'Waterfall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '51815585498e0a971f9cbf3c',
#     'name': 'cachoeira do horto',
#     'location': {'lat': -22.964821484923018,
#      'lng': -43.229177173607546,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.964821484923018,
#        'lng': -43.229177173607546}],
#      'distance': 4663,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4deefb944765f83613cdba6e',
#       'name': 'Historic Site',
#       'pluralName': 'Historic Sites',
#       'shortName': 'Historic Site',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '4d62939fd7206ea8218d0cf2',
#     'name': 'Cachoeira da Gruta',
#     'location': {'lat': -22.965679958488845,
#      'lng': -43.238743882366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.965679958488845,
#        'lng': -43.238743882366}],
#      'distance': 5619,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4bf58dd8d48988d159941735',
#       'name': 'Trail',
#       'pluralName': 'Trails',
#       'shortName': 'Trail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '4e4841c745dd2955e5b0635b',
#     'name': 'Posto Shell Cachoeira',
#     'location': {'address': 'Av. Rui Barbosa, 86',
#      'lat': -22.914411676562846,
#      'lng': -43.08405076049432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.914411676562846,
#        'lng': -43.08405076049432}],
#      'distance': 12114,
#      'postalCode': '24310-005',
#      'cc': 'BR',
#      'city': 'Niterói',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Av. Rui Barbosa, 86', 'Niterói, RJ', '24310-005']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '53767223498ee3757140833c',
#     'name': 'Cachoeira de Sabores',
#     'location': {'address': 'Rua do Bispo 94',
#      'lat': -22.92362403869629,
#      'lng': -43.211124420166016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.92362403869629,
#        'lng': -43.211124420166016}],
#      'distance': 6041,
#      'postalCode': '20261-064',
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua do Bispo 94',
#       'Rio de Janeiro, RJ',
#       '20261-064']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '4feb09c1011cb5f5fe07afa4',
#     'name': 'Cachoeira das Almas',
#     'location': {'address': 'Caminho das Almas,',
#      'crossStreet': 'Alto da Boa Vista',
#      'lat': -22.9514976092273,
#      'lng': -43.28237771987915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.9514976092273,
#        'lng': -43.28237771987915}],
#      'distance': 10303,
#      'postalCode': '20531-240',
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Caminho das Almas, (Alto da Boa Vista)',
#       'Rio de Janeiro, RJ',
#       '20531-240']},
#     'categories': [{'id': '4bf58dd8d48988d159941735',
#       'name': 'Trail',
#       'pluralName': 'Trails',
#       'shortName': 'Trail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '587bafe9e72ef632147b3eec',
#     'name': 'Cachoeira Solar da Imperatriz',
#     'location': {'lat': -22.96932,
#      'lng': -43.247234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.96932,
#        'lng': -43.247234}],
#      'distance': 6452,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '56aa371be4b08b9a8d573560',
#       'name': 'Waterfall',
#       'pluralName': 'Waterfalls',
#       'shortName': 'Waterfall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '60045d171bff7d34b3c794ba',
#     'name': 'Cachoeira Do Amor',
#     'location': {'lat': -22.96553,
#      'lng': -43.277413,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.96553,
#        'lng': -43.277413}],
#      'distance': 9565,
#      'postalCode': '20531-573',
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rio de Janeiro, RJ', '20531-573']},
#     'categories': [{'id': '56aa371be4b08b9a8d573560',
#       'name': 'Waterfall',
#       'pluralName': 'Waterfalls',
#       'shortName': 'Waterfall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '54564d12498eca78acdf8c87',
#     'name': 'Cachoeira Jequitibá',
#     'location': {'address': 'Parque Nacional da Tijuca',
#      'lat': -22.964968558739997,
#      'lng': -43.24712329425976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.964968558739997,
#        'lng': -43.24712329425976}],
#      'distance': 6481,
#      'cc': 'BR',
#      'country': 'Brasil',
#      'formattedAddress': ['Parque Nacional da Tijuca']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '52dff4cc11d2f34f6b51cb28',
#     'name': 'Cachoeira da capela',
#     'location': {'lat': -22.966216,
#      'lng': -43.280534,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.966216,
#        'lng': -43.280534}],
#      'distance': 9879,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4eb1d4d54b900d56c88a45fc',
#       'name': 'Mountain',
#       'pluralName': 'Mountains',
#       'shortName': 'Mountain',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '54e37582498ef55418f283ae',
#     'name': 'Cachoeira dos Gravatas',
#     'location': {'lat': -22.92937,
#      'lng': -43.267523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.92937,
#        'lng': -43.267523}],
#      'distance': 9756,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '52e81612bcbc57f1066b7a13',
#       'name': 'Nature Preserve',
#       'pluralName': 'Nature Preserves',
#       'shortName': 'Preserve',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/naturepreserve_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5321fbc7498e48d205a6a9fc',
#     'name': 'Cachoeira da Pedra da Gavea',
#     'location': {'lat': -22.999939,
#      'lng': -43.294771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.999939,
#        'lng': -43.294771}],
#      'distance': 11737,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4eb1d4dd4b900d56c88a45fd',
#       'name': 'River',
#       'pluralName': 'Rivers',
#       'shortName': 'River',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5287775011d2a8114f55ba97',
#     'name': 'Cachoeira Plantas',
#     'location': {'address': 'Avenida Rui Barbosa 326',
#      'lat': -22.913164177857283,
#      'lng': -43.08015567438429,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.913164177857283,
#        'lng': -43.08015567438429}],
#      'distance': 12526,
#      'cc': 'BR',
#      'city': 'Niterói',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Avenida Rui Barbosa 326', 'Niterói, RJ']},
#     'categories': [{'id': '4eb1c0253b7b52c0e1adc2e9',
#       'name': 'Garden Center',
#       'pluralName': 'Garden Centers',
#       'shortName': 'Garden Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/gardencenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5286492f11d212b55a858bce',
#     'name': 'cachoeira paulista sp',
#     'location': {'lat': -22.937261527789115,
#      'lng': -43.33498492865776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.937261527789115,
#        'lng': -43.33498492865776}],
#      'distance': 15917,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5143de3ee4b0bd8371a04167',
#     'name': 'Cachoeiras',
#     'location': {'lat': -22.897497932466646,
#      'lng': -43.18267830966442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.897497932466646,
#        'lng': -43.18267830966442}],
#      'distance': 8291,
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rio de Janeiro, RJ']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '4fb3081fe4b0a14f424366fd',
#     'name': 'Cachoeira Turiaçu',
#     'location': {'lat': -22.858959197998047,
#      'lng': -43.34186935424805,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.858959197998047,
#        'lng': -43.34186935424805}],
#      'distance': 20472,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4eb1baf03b7b2c5b1d4306ca',
#       'name': 'Stables',
#       'pluralName': 'Stables',
#       'shortName': 'Stables',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/stable_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '4ec2c2755c5c5b2f994e6098',
#     'name': 'Estrada da Cachoeira',
#     'location': {'address': 'Estr. da Cachoeira',
#      'lat': -22.912396576108325,
#      'lng': -43.07841179178301,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.912396576108325,
#        'lng': -43.07841179178301}],
#      'distance': 12723,
#      'cc': 'BR',
#      'city': 'Niterói',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Estr. da Cachoeira', 'Niterói, RJ']},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '51477fa6e4b0ee6562769fb8',
#     'name': 'Descida Da Cachoeira - LB',
#     'location': {'lat': -22.911052,
#      'lng': -43.072248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.911052,
#        'lng': -43.072248}],
#      'distance': 13342,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '54bc5bcc498e5ac87c3895cc',
#     'name': 'Cachoeira Grande',
#     'location': {'address': 'Estrada Da Cachoeira',
#      'lat': -22.85863555916961,
#      'lng': -43.372900955585266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.85863555916961,
#        'lng': -43.372900955585266}],
#      'distance': 23085,
#      'cc': 'BR',
#      'city': 'Piabetá',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Estrada Da Cachoeira', 'Piabetá, RJ']},
#     'categories': [{'id': '4eb1d4dd4b900d56c88a45fd',
#       'name': 'River',
#       'pluralName': 'Rivers',
#       'shortName': 'River',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5175f40be4b005c5cac85935',
#     'name': 'Cachoeiras de Macacu',
#     'location': {'lat': -22.838788003562254,
#      'lng': -43.099613897771306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.838788003562254,
#        'lng': -43.099613897771306}],
#      'distance': 17183,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4eb1d4dd4b900d56c88a45fd',
#       'name': 'River',
#       'pluralName': 'Rivers',
#       'shortName': 'River',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5217d40d11d2b8e8321d73b8',
#     'name': 'estrada da cachoeira',
#     'location': {'lat': -22.908060589046848,
#      'lng': -43.06605599100309,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.908060589046848,
#        'lng': -43.06605599100309}],
#      'distance': 14058,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '5341cb3b498e25d8c574e1e6',
#     'name': 'Sushi Cachoeira',
#     'location': {'lat': -22.973284700771718,
#      'lng': -43.33262748162795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.973284700771718,
#        'lng': -43.33262748162795}],
#      'distance': 15198,
#      'cc': 'BR',
#      'country': 'Brasil'},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False},
#    {'id': '50d534f5e4b0aceb0f060ffe',
#     'name': 'Bar do Cachoeira',
#     'location': {'address': 'Rua luz',
#      'lat': -22.955723366911336,
#      'lng': -43.35447203857968,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -22.955723366911336,
#        'lng': -43.35447203857968}],
#      'distance': 17531,
#      'cc': 'BR',
#      'city': 'Rio de Janeiro',
#      'state': 'RJ',
#      'country': 'Brasil',
#      'formattedAddress': ['Rua luz', 'Rio de Janeiro, RJ']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1623022111',
#     'hasPerk': False}]}}

# %%
#select only the venues
venues = results['response']['venues']

#transform json into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.head()
# Out:
#                          id                          name  \
# 0  4bc1cda674a9a5938e3ed2f6         Cachoeira do Chuveiro
# 1  501a7ff8e4b04620d5ff1ceb  Cachoeira do Jardim Botânico
# 2  5416fc37498ec124d60fac7c            Cachoeira do Horto
# 3  53556b5b498ed5c9b3a22f54        Cachoeira dos Primatas
# 4  4c8d062555fba093eb8b64ab        Cachoeira dos Primatas
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4eb1d4dd4b900d56c88a45fd', 'name': 'R...  v-1623022111    False
# 1  [{'id': '56aa371be4b08b9a8d573560', 'name': 'W...  v-1623022111    False
# 2  [{'id': '56aa371be4b08b9a8d573560', 'name': 'W...  v-1623022111    False
# 3  [{'id': '4bf58dd8d48988d159941735', 'name': 'T...  v-1623022111    False
# 4  [{'id': '4eb1d4dd4b900d56c88a45fd', 'name': 'R...  v-1623022111    False
#
#                     location.address       location.crossStreet  location.lat  \
# 0             Estrada Dona Castorina  Parque Nacional da Tijuca    -22.966324
# 1  Jardim Botânico do Rio de Janeiro                        NaN    -22.969508
# 2                                NaN                        NaN    -22.965870
# 3                                NaN                        NaN    -22.981304
# 4          Parque Nacional da Tijuca                        NaN    -22.958412
#
#    location.lng                            location.labeledLatLngs  \
# 0    -43.242868  [{'label': 'display', 'lat': -22.9663243574554...
# 1    -43.224679  [{'label': 'display', 'lat': -22.9695075649558...
# 2    -43.235182  [{'label': 'display', 'lat': -22.9658701606438...
# 3    -43.221855  [{'label': 'display', 'lat': -22.9813041687011...
# 4    -43.228018  [{'label': 'display', 'lat': -22.9584122732009...
#
#    location.distance location.postalCode location.cc   location.city  \
# 0               6031           22460-320          BR  Rio de Janeiro
# 1               4143           22470-180          BR  Rio de Janeiro
# 2               5254                 NaN          BR             NaN
# 3               3982                 NaN          BR             NaN
# 4               4723                 NaN          BR  Rio de Janeiro
#
#   location.state location.country  \
# 0             RJ           Brasil
# 1             RJ           Brasil
# 2            NaN           Brasil
# 3            NaN           Brasil
# 4             RJ           Brasil
#
#                            location.formattedAddress
# 0  [Estrada Dona Castorina (Parque Nacional da Ti...
# 1  [Jardim Botânico do Rio de Janeiro, Rio de Jan...
# 2                                                NaN
# 3                                                NaN
# 4    [Parque Nacional da Tijuca, Rio de Janeiro, RJ]

# %% [markdown]
# <h3>3. Displaying the data </h3>

# %% [markdown]
# After transform the data into a dataframe, now we need to clean the data, filter the important features and, finally, plot it inside a map.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                            name categories                            address  \
# 0         Cachoeira do Chuveiro      River             Estrada Dona Castorina
# 1  Cachoeira do Jardim Botânico  Waterfall  Jardim Botânico do Rio de Janeiro
# 2            Cachoeira do Horto  Waterfall                                NaN
# 3        Cachoeira dos Primatas      Trail                                NaN
# 4        Cachoeira dos Primatas      River          Parque Nacional da Tijuca
#
#                  crossStreet        lat        lng  \
# 0  Parque Nacional da Tijuca -22.966324 -43.242868
# 1                        NaN -22.969508 -43.224679
# 2                        NaN -22.965870 -43.235182
# 3                        NaN -22.981304 -43.221855
# 4                        NaN -22.958412 -43.228018
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -22.9663243574554...      6031  22460-320  BR
# 1  [{'label': 'display', 'lat': -22.9695075649558...      4143  22470-180  BR
# 2  [{'label': 'display', 'lat': -22.9658701606438...      5254        NaN  BR
# 3  [{'label': 'display', 'lat': -22.9813041687011...      3982        NaN  BR
# 4  [{'label': 'display', 'lat': -22.9584122732009...      4723        NaN  BR
#
#              city state country  \
# 0  Rio de Janeiro    RJ  Brasil
# 1  Rio de Janeiro    RJ  Brasil
# 2             NaN   NaN  Brasil
# 3             NaN   NaN  Brasil
# 4  Rio de Janeiro    RJ  Brasil
#
#                                     formattedAddress                        id
# 0  [Estrada Dona Castorina (Parque Nacional da Ti...  4bc1cda674a9a5938e3ed2f6
# 1  [Jardim Botânico do Rio de Janeiro, Rio de Jan...  501a7ff8e4b04620d5ff1ceb
# 2                                                NaN  5416fc37498ec124d60fac7c
# 3                                                NaN  53556b5b498ed5c9b3a22f54
# 4    [Parque Nacional da Tijuca, Rio de Janeiro, RJ]  4c8d062555fba093eb8b64ab

# %%
#displaying all categories
dataframe_filtered[['categories']].value_counts()
# Out:
# categories
# River                   5
# Waterfall               5
# Road                    3
# Trail                   3
# Bar                     2
# Church                  1
# Garden Center           1
# Gas Station             1
# Historic Site           1
# Mountain                1
# Nature Preserve         1
# Other Great Outdoors    1
# Snack Place             1
# Stables                 1
# Sushi Restaurant        1
# dtype: int64

# %% [markdown]
# Considering that 'cachoeira' can be used in multiple venues beyond the place itself, it is important to filter undesired results, as shown below. In order to simplify, only some categories were chosen, mostly related to the purpose.

# %%
#Filter for categories
places = ['Waterfall', 'River', 'Other Great Outdoors', 'Mountain', 'Nature Preserve', 'Trail']
df_filtered = dataframe_filtered[dataframe_filtered.categories.isin(places)]
df_filtered.describe(include = 'all')
# Out:
#                           name categories                    address  \
# count                       16         16                          7
# unique                      15          6                          6
# top     Cachoeira dos Primatas      River  Parque Nacional da Tijuca
# freq                         2          5                          2
# mean                       NaN        NaN                        NaN
# std                        NaN        NaN                        NaN
# min                        NaN        NaN                        NaN
# 25%                        NaN        NaN                        NaN
# 50%                        NaN        NaN                        NaN
# 75%                        NaN        NaN                        NaN
# max                        NaN        NaN                        NaN
#
#                       crossStreet        lat        lng  \
# count                           2  16.000000  16.000000
# unique                          2        NaN        NaN
# top     Parque Nacional da Tijuca        NaN        NaN
# freq                            1        NaN        NaN
# mean                          NaN -22.950383 -43.249488
# std                           NaN   0.042391   0.055047
# min                           NaN -22.999939 -43.372901
# 25%                           NaN -22.967073 -43.278193
# 50%                           NaN -22.965605 -43.244995
# 75%                           NaN -22.953950 -43.230229
# max                           NaN -22.838788 -43.099614
#
#                                            labeledLatLngs    distance  \
# count                                                  16     16.0000
# unique                                                 16         NaN
# top     [{'label': 'display', 'lat': -22.966216, 'lng'...         NaN
# freq                                                    1         NaN
# mean                                                  NaN   8708.7500
# std                                                   NaN   5188.8938
# min                                                   NaN   3982.0000
# 25%                                                   NaN   5227.2500
# 50%                                                   NaN   6466.5000
# 75%                                                   NaN   9985.0000
# max                                                   NaN  23085.0000
#
#        postalCode   cc            city state country  \
# count           4   16               7     7      16
# unique          4    1               2     1       1
# top     22470-180   BR  Rio de Janeiro    RJ  Brasil
# freq            1   16               6     7      16
# mean          NaN  NaN             NaN   NaN     NaN
# std           NaN  NaN             NaN   NaN     NaN
# min           NaN  NaN             NaN   NaN     NaN
# 25%           NaN  NaN             NaN   NaN     NaN
# 50%           NaN  NaN             NaN   NaN     NaN
# 75%           NaN  NaN             NaN   NaN     NaN
# max           NaN  NaN             NaN   NaN     NaN
#
#                                          formattedAddress  \
# count                                                   8
# unique                                                  8
# top     [Jardim Botânico do Rio de Janeiro, Rio de Jan...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                               id
# count                         16
# unique                        16
# top     54e37582498ef55418f283ae
# freq                           1
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %% [markdown]
# By reducing the number of venues, we expect to see these spots distributed in a map. So red markers will be added to mark the initial position and blue markers to show the multiple options.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=12) 

# add a red circle marker to represent the Copacabana Beach
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Copacabana beach',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add blue circle markers to represent all filtered waterfalls
for lat, lng, category, name in zip(df_filtered.lat, df_filtered.lng, df_filtered.categories, df_filtered.name):
    label = '{}, {}'.format(category, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ac75ac3d414942139079da3a9128c436%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ac75ac3d414942139079da3a9128c436%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ac75ac3d414942139079da3a9128c436%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ac75ac3d414942139079da3a9128c436%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-22.9719642%2C%20-43.1843432%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Even though the number of option is not big, it is impossible to visit of all of them. As we can see, some of them are really far from the initial position. To reduce even more, we will see the distance and try to focus on the nearest spots.

# %%
#display the distribution of waterfalls in terms of distance
plt.hist(df_filtered.distance)
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.show()

# %%
# reducing the options to a maximum of 10 km
df_filtered2 = df_filtered[df_filtered.distance <= 10000]

# %%
# removing duplicated data
df_filtered3 = df_filtered2.drop(index = 3, axis = 0)

# %%
df_filtered3.reset_index(drop = True)
df_filtered3.head()
# Out:
#                            name categories                            address  \
# 0         Cachoeira do Chuveiro      River             Estrada Dona Castorina
# 1  Cachoeira do Jardim Botânico  Waterfall  Jardim Botânico do Rio de Janeiro
# 2            Cachoeira do Horto  Waterfall                                NaN
# 4        Cachoeira dos Primatas      River          Parque Nacional da Tijuca
# 5       Cachoeira das Paineiras  Waterfall                          Paineiras
#
#                  crossStreet        lat        lng  \
# 0  Parque Nacional da Tijuca -22.966324 -43.242868
# 1                        NaN -22.969508 -43.224679
# 2                        NaN -22.965870 -43.235182
# 4                        NaN -22.958412 -43.228018
# 5                        NaN -22.954767 -43.230966
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -22.9663243574554...      6031  22460-320  BR
# 1  [{'label': 'display', 'lat': -22.9695075649558...      4143  22470-180  BR
# 2  [{'label': 'display', 'lat': -22.9658701606438...      5254        NaN  BR
# 4  [{'label': 'display', 'lat': -22.9584122732009...      4723        NaN  BR
# 5  [{'label': 'display', 'lat': -22.954767, 'lng'...      5147        NaN  BR
#
#              city state country  \
# 0  Rio de Janeiro    RJ  Brasil
# 1  Rio de Janeiro    RJ  Brasil
# 2             NaN   NaN  Brasil
# 4  Rio de Janeiro    RJ  Brasil
# 5  Rio de Janeiro    RJ  Brasil
#
#                                     formattedAddress                        id
# 0  [Estrada Dona Castorina (Parque Nacional da Ti...  4bc1cda674a9a5938e3ed2f6
# 1  [Jardim Botânico do Rio de Janeiro, Rio de Jan...  501a7ff8e4b04620d5ff1ceb
# 2                                                NaN  5416fc37498ec124d60fac7c
# 4    [Parque Nacional da Tijuca, Rio de Janeiro, RJ]  4c8d062555fba093eb8b64ab
# 5                    [Paineiras, Rio de Janeiro, RJ]  587e4862102f470580acfb47

# %%
df_filtered3.shape
# Out:
# (11, 16)

# %% [markdown]
# <h3>4. Rating the filtered data</h3>

# %% [markdown]
# From this point, we know that we reduce our dataset to 11 options. However, in order to make sure these options are feasible, this tourist wants to evaluate if these waterfalls are safe to visit and the easiest way to do it is by getting the ratings other people gave in Foursquare.

# %%
# run a loop to query the rating from each venue in dataframe
list_venues = []
for venue in df_filtered3['id']:
    url_venues = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
    result = requests.get(url_venues).json()
    try:
        list_venues.append(result['response']['venue']['rating'])
    except:
        list_venues.append(0)

# %%
list_venues
# Out:
# [7.9, 7.7, 7.6, 8.2, 0, 0, 0, 0, 0, 0, 0]

# %%
# add rating column and values to the dataframe
df_filtered3['rating'] = pd.Series(list_venues).values
df_filtered3.head()
# Out:
#                            name categories                            address  \
# 0         Cachoeira do Chuveiro      River             Estrada Dona Castorina
# 1  Cachoeira do Jardim Botânico  Waterfall  Jardim Botânico do Rio de Janeiro
# 2            Cachoeira do Horto  Waterfall                                NaN
# 4        Cachoeira dos Primatas      River          Parque Nacional da Tijuca
# 5       Cachoeira das Paineiras  Waterfall                          Paineiras
#
#                  crossStreet        lat        lng  \
# 0  Parque Nacional da Tijuca -22.966324 -43.242868
# 1                        NaN -22.969508 -43.224679
# 2                        NaN -22.965870 -43.235182
# 4                        NaN -22.958412 -43.228018
# 5                        NaN -22.954767 -43.230966
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -22.9663243574554...      6031  22460-320  BR
# 1  [{'label': 'display', 'lat': -22.9695075649558...      4143  22470-180  BR
# 2  [{'label': 'display', 'lat': -22.9658701606438...      5254        NaN  BR
# 4  [{'label': 'display', 'lat': -22.9584122732009...      4723        NaN  BR
# 5  [{'label': 'display', 'lat': -22.954767, 'lng'...      5147        NaN  BR
#
#              city state country  \
# 0  Rio de Janeiro    RJ  Brasil
# 1  Rio de Janeiro    RJ  Brasil
# 2             NaN   NaN  Brasil
# 4  Rio de Janeiro    RJ  Brasil
# 5  Rio de Janeiro    RJ  Brasil
#
#                                     formattedAddress  \
# 0  [Estrada Dona Castorina (Parque Nacional da Ti...
# 1  [Jardim Botânico do Rio de Janeiro, Rio de Jan...
# 2                                                NaN
# 4    [Parque Nacional da Tijuca, Rio de Janeiro, RJ]
# 5                    [Paineiras, Rio de Janeiro, RJ]
#
#                          id  rating
# 0  4bc1cda674a9a5938e3ed2f6     7.9
# 1  501a7ff8e4b04620d5ff1ceb     7.7
# 2  5416fc37498ec124d60fac7c     7.6
# 4  4c8d062555fba093eb8b64ab     8.2
# 5  587e4862102f470580acfb47     0.0

# %%
# splitting the data rated and unrated
rated = df_filtered3[df_filtered3.rating > 0]
unrated = df_filtered3[df_filtered3.rating == 0]

# %%
rated
# Out:
#                            name categories                            address  \
# 0         Cachoeira do Chuveiro      River             Estrada Dona Castorina
# 1  Cachoeira do Jardim Botânico  Waterfall  Jardim Botânico do Rio de Janeiro
# 2            Cachoeira do Horto  Waterfall                                NaN
# 4        Cachoeira dos Primatas      River          Parque Nacional da Tijuca
#
#                  crossStreet        lat        lng  \
# 0  Parque Nacional da Tijuca -22.966324 -43.242868
# 1                        NaN -22.969508 -43.224679
# 2                        NaN -22.965870 -43.235182
# 4                        NaN -22.958412 -43.228018
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -22.9663243574554...      6031  22460-320  BR
# 1  [{'label': 'display', 'lat': -22.9695075649558...      4143  22470-180  BR
# 2  [{'label': 'display', 'lat': -22.9658701606438...      5254        NaN  BR
# 4  [{'label': 'display', 'lat': -22.9584122732009...      4723        NaN  BR
#
#              city state country  \
# 0  Rio de Janeiro    RJ  Brasil
# 1  Rio de Janeiro    RJ  Brasil
# 2             NaN   NaN  Brasil
# 4  Rio de Janeiro    RJ  Brasil
#
#                                     formattedAddress  \
# 0  [Estrada Dona Castorina (Parque Nacional da Ti...
# 1  [Jardim Botânico do Rio de Janeiro, Rio de Jan...
# 2                                                NaN
# 4    [Parque Nacional da Tijuca, Rio de Janeiro, RJ]
#
#                          id  rating
# 0  4bc1cda674a9a5938e3ed2f6     7.9
# 1  501a7ff8e4b04620d5ff1ceb     7.7
# 2  5416fc37498ec124d60fac7c     7.6
# 4  4c8d062555fba093eb8b64ab     8.2

# %% [markdown]
# <h3>5. Conclusion </h3>

# %% [markdown]
# After displaying the plot with all the possible results and all further analysis developed later to reduce the options, it is possible to display a new graph. At this time, locations that were rated will be chosen by the tourist, because all of them received good scores (> 7.0), and they will appear in a yellow dot. The unrated will be displayed in blue dots as in the previous one.

# %%
venues_map_reviewed = folium.Map(location=[latitude, longitude], zoom_start=13) 

folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Copacabana beach',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map_reviewed)

# markers for chosen locations
for lat, lng, category, name in zip(rated.lat, rated.lng, rated.categories, rated.name):
    label = '{}, {}'.format(category, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        color='yellow',
        popup=label,
        fill = True,
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(venues_map_reviewed)
    
# markers for the other locations
for lat, lng, category, name in zip(unrated.lat, unrated.lng, unrated.categories, unrated.name):
    label = '{}, {}'.format(category, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map_reviewed)

venues_map_reviewed
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4e4b667c220043d68d68ca55d51303cc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4e4b667c220043d68d68ca55d51303cc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4e4b667c220043d68d68ca55d51303cc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4e4b667c220043d68d68ca55d51303cc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-22.9719642%2C%20-43.1843432%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...
